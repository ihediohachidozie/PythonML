# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver import Keys

# %%
driver = webdriver.Chrome()
url  = "https://www.vehicle-operator-licensing.service.gov.uk/view-details/licence/1"
driver.get("https://www.vehicle-operator-licensing.service.gov.uk/zemen-know-awake-in-Ile-there-goe-neuer-Lizard-i?d=www.vehicle-operator-licensing.service.gov.uk")

# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("https://www.vehicle-operator-licensing.service.gov.uk/zemen-know-awake-in-Ile-there-goe-neuer-Lizard-i?d=www.vehicle-operator-licensing.service.gov.uk")
page.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(page.text, 'html')

# %%
soup.text
# Out:
# '(function(){function e8(xI){return "\\\\u"+("0000"+xI.charCodeAt(0).toString(16)).substr(-4);}function xB(WY,I7){var CF=WY;var gL=I7;return function(){var C7=CF;var TT=gL;CF=TT;C7^=C7<<23;C7^=C7>>17;C7^=TT;C7^=TT>>26;gL=C7;return (CF+gL)%4294967296;};}var s7=113;var TX=0;var Wb=[];var dV=0;var Jj="...";var f1=window.atob(Jj);var NY=[];var fe=f1.length;while(dV>cv|mW[QH]<<8-cv)&255);QH+=1;}var i6=py;var NQ=[];var ir=0;var PQ=[106,109,159,223,94,125,132,152,246,227,219,75,179,55,254,21,179,145,224,31,207,73,141,158,26,55,190,95,253].length;var ek=0;var we="...";var iN=window.atob(we);var Fo=iN.length;var Ok=[];while(ek>>8^ao[(Nz^H9[d_.substr(1505, 10)](sP))&255];sP+=1;}var Nx=Lx;Nx;var Mo=0;var tz=typeof 1277455618!==qI.substr(404, 6)?Bl.substr(631, 0)+1277455618:1277455618;while(Mo>>8^ao[(Nz^tz[d_.substr(1505, 10)](Mo))&255];Mo+=1;}var SQ=1277455618;SQ;var rM=1;var rU=false;function qf(Xk){var K2=0;var C8=[d_.substr(234, 22),qI.substr(365, 8),qI.substr(290, 9),Bl.substr(1191, 11),d_.
# ...
