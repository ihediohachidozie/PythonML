# %%
import pandas as pd

# %%
df = pd.read_excel('data/BatBowlStats.xlsx')

# %%
df[df['Data Type'] == 'Bat']
# Out:
#                              Format Data Type Bat_Format  Bat_Mat Bat_Inns  \
# 0        Aakash Chopra Career Stats       Bat      Tests     10.0       19
# 1        Aakash Chopra Career Stats       Bat         FC    162.0      266
# 2        Aakash Chopra Career Stats       Bat     List A     65.0       61
# 3        Aakash Chopra Career Stats       Bat       T20s     21.0       19
# 8          Aamer Azmat Career Stats       Bat     List A     11.0       11
# ...                             ...       ...        ...      ...      ...
# 34449  Zunaed Siddique Career Stats       Bat       ODIs     54.0       53
# 34450  Zunaed Siddique Career Stats       Bat      T20Is      7.0        7
# 34451  Zunaed Siddique Career Stats       Bat         FC    152.0      264
# 34452  Zunaed Siddique Career Stats       Bat     List A    188.0      186
# 34453  Zunaed Siddique Career Stats       Bat       T20s     78.0       77
#
# ...
