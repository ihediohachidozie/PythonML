# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
#from selenium.webdriver import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from datetime import datetime
import pytz
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.apartments.com/atlanta-ga'
start = datetime.now(pytz.timezone('America/New_York')).strftime("%Y-%m-%d %I:%M %p %Z")

# %%
driver = webdriver.Chrome()
driver.implicitly_wait(10) # wait for 10 seconds
driver.get(url)
try:
    wait = WebDriverWait(driver, 10)
    element = wait.until(EC.presence_of_element_located((By.ID, "paging")))
    pagination = driver.find_element(By.XPATH, "/html/body/div[1]/main/section/div[1]/section[2]/div[2]/ul/li[41]/p/span").text.split()[-1]
    
finally:
    driver.quit()
pagination
# Out:
# '18'

# %%
def get_pages(pagination, url):
    for x in range(1, int(pagination)):
        #link = '/' + str(x)
        #url = url + link
        driver = webdriver.Chrome()
        #driver.implicitly_wait(10) # wait for 10 seconds
        driver.get(url + '/' + str(x))
        try:
            wait = WebDriverWait(driver, 10)
            element = wait.until(EC.presence_of_element_located((By.ID, "placardContainer")))
            yield driver.page_source
            #url.replace(link, '')
        finally:
            driver.quit()
        
        #
        
        #driver.close()

# %%
# loop through the pages
pages = []

for page in get_pages(pagination, url):
    pages.append(page)

len(pages)
# Out:
# 17

# %%
end = datetime.now(pytz.timezone('America/New_York')).strftime("%Y-%m-%d %I:%M %p %Z")

# %%
master_list = []
for x in range(len(pages)):
    soup = BeautifulSoup(pages[x], 'html')
    placardContainer = soup.find('div', {'id': 'placardContainer'})
    mortarWrapper = placardContainer.find_all('li', {'class':'mortar-wrapper'})
    for item in get_listing(mortarWrapper):
        master_list.append(item)
    #break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 6
#       4 placardContainer = soup.find('div', {'id': 'placardContainer'})
#       5 mortarWrapper = placardContainer.find_all('li', {'class':'mortar-wrapper'})
# ----> 6 for item in get_listing(mortarWrapper):
#       7     master_list.append(item)
#
# Cell In[66], line 12, in get_listing(page)
#       9     row['LISTING_NAME'] = None
#      11 row['LISTING_LINK'] = data.find('a', {'class':"property-link"})['href']
# ---> 12 meta = data.find('p', {'class':"property-beds"}).text.split(' - ')
#      13 row['LISTING_USE'] = meta[0] if len(meta) > 1 else None
#      14 row['LISTING_ADDRESS'] = data.find('div', {'class':"property-address"}).text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
def get_listing(page):
    for data in page:
        row = {}
        row['SCRAPE_TIME'] = start
        row['REQUEST_TIME'] = end
        try:
            row['LISTING_NAME'] = data.find('div', {'class':"property-title"}).text
        except:
            row['LISTING_NAME'] = None
            
        row['LISTING_LINK'] = data.find('a', {'class':"property-link"})['href']
        try:
            meta = data.find('p', {'class':"property-beds"}).text.split(' - ')
            row['LISTING_USE'] = meta[0] if len(meta) > 1 else None
            row['LISTING_ADDRESS'] = data.find('div', {'class':"property-address"}).text
        except:
            row['LISTING_USE'] = None
            row['LISTING_ADDRESS'] = None
        
        try:
            row['LISTING_DESCRIPTION'] = data.find('p', {'class':"property-amenities"}).text.strip().replace('\n',', ')
        except:
            row['SPECIAL_TEXT'] = None
            
        try:
            video_virtual = data.find('ul', {'class':"mediaLinksList"}).text.strip().split('\n')
        except:
            video_virtual = []
            row['HAS_VIDEOS'] = True if 'Videos' in video_virtual else False
            row['HAS_VIRTUAL_TOUR'] = True if 'Virtual Tour' in video_virtual else False
        try:
            check_email = data.find('button', {'class':"checkAvailability"}).text
            row['HAS_EMAIL'] = True if check_email == 'Email' else False
        except:
            row['HAS_EMAIL'] = False
        
        row['PRICE'] = data.find('p', {'class':"property-pricing"}).text
        
        try:
            row['PHONE_NUMBER'] = data.find('div', {'class':"property-actions"}).span.text
        except:
            row['PHONE_NUMBER'] = None
            
        row['HAS_IMAGE'] = True if len(data.find('div', {'class':"item active us"}).img['src']) > 0 else False
        
        try:
            row['SPECIAL_TEXT'] = data.find_all('a', {'class':"property-link"})[-2].span.text
        except:
            row['SPECIAL_TEXT'] = None 
        yield row

# %%
header = ['SCRAPE_TIME',
    'REQUEST_TIME',
    'LISTING_NAME',
    'LISTING_LINK',
    'LISTING_USE',
    'LISTING_ADDRESS',
    'LISTING_DESCRIPTION',
    'HAS_VIDEOS',
    'HAS_VIRTUAL_TOUR',
    'HAS_EMAIL',
    'PRICE',
    'PHONE_NUMBER',
    'HAS_IMAGE',
    'SPECIAL_TEXT']

# %%
def get_listing1(page):
    dataList= []
    for data in page:
        row = {}
        row['SCRAPE_TIME'] = start
        row['REQUEST_TIME'] = end
        row['LISTING_NAME'] = data.find('div', {'class':"property-title"}).text
        row['LISTING_LINK'] = data.find('a', {'class':"property-link"})['href']
        meta = data.find('p', {'class':"property-beds"}).text.split(' - ')
        row['LISTING_USE'] = meta[0] if len(meta) > 1 else None
        row['LISTING_ADDRESS'] = data.find('div', {'class':"property-address"}).text
        row['LISTING_DESCRIPTION'] = data.find('p', {'class':"property-amenities"}).text.strip().replace('\n',', ')
        video_virtual = data.find('ul', {'class':"mediaLinksList"}).text.strip().split('\n')
        row['HAS_VIDEOS'] = True if 'Videos' in video_virtual else False
        row['HAS_VIRTUAL_TOUR'] = True if 'Virtual Tour' in video_virtual else False
        check_email = data.find('button', {'class':"checkAvailability"}).text
        row['HAS_EMAIL'] = True if check_email == 'Email' else False
        row['PRICE'] = data.find('p', {'class':"property-pricing"}).text
        row['PHONE_NUMBER'] = data.find('div', {'class':"property-actions"}).span.text
        row['HAS_IMAGE'] = True if len(data.find('div', {'class':"item active us"}).img['src']) > 0 else False
        try:
            row['SPECIAL_TEXT'] = data.find_all('a', {'class':"property-link"})[-2].span.text
        except:
            row['SPECIAL_TEXT'] = None
        dataList.append(row)
    
    return dataList

# %%
len(master_list)
# Out:
# 404

# %%
df = pd.DataFrame(master_list, columns=header)

# %%
df.to_csv('data/apartments.csv', index=False)

# %%
df
# Out:
#                  SCRAPE_TIME             REQUEST_TIME  \
# 0    2024-01-31 11:17 AM EST  2024-01-31 11:31 AM EST
# 1    2024-01-31 11:17 AM EST  2024-01-31 11:31 AM EST
# 2    2024-01-31 11:17 AM EST  2024-01-31 11:31 AM EST
# 3    2024-01-31 11:17 AM EST  2024-01-31 11:31 AM EST
# 4    2024-01-31 11:17 AM EST  2024-01-31 11:31 AM EST
# ..                       ...                      ...
# 399  2024-01-31 11:17 AM EST  2024-01-31 11:31 AM EST
# 400  2024-01-31 11:17 AM EST  2024-01-31 11:31 AM EST
# 401  2024-01-31 11:17 AM EST  2024-01-31 11:31 AM EST
# 402  2024-01-31 11:17 AM EST  2024-01-31 11:31 AM EST
# 403  2024-01-31 11:17 AM EST  2024-01-31 11:31 AM EST
#
#                  LISTING_NAME  \
# 0               3005 Buckhead
# 1                      Annett
# 2         Platform Grant Park
# 3              Dunwoody Ridge
# 4    Cortland at Phipps Plaza
# ..                        ...
# 399     Retreat at Greenbriar
# 400  The Pointe at Lenox Park
# 401          The Emerson 1600
# 402      Maple Lakes Townhome
# 403              Regency Park
#
#                                           LISTING_LINK LISTING_USE  \
# 0    https://www.apartments.com/3005-buckhead-atlan...      Studio
# 1    https://www.apartments.com/annett-atlanta-ga/3...      Studio
# 2    https://www.apartments.com/platform-grant-park...      Studio
# 3    https://www.apartments.com/dunwoody-ridge-atla...        None
# 4    https://www.apartments.com/cortland-at-phipps-...      Studio
# ..                                                 ...         ...
# 399  https://www.apartments.com/retreat-at-greenbri...      Studio
# 400  https://www.apartments.com/the-pointe-at-lenox...        None
# 401  https://www.apartments.com/the-emerson-1600-sm...        None
# 402  https://www.apartments.com/maple-lakes-townhom...        None
# 403  https://www.apartments.com/regency-park-east-p...      Studio
#
#                                        LISTING_ADDRESS  \
# 0              3005 Peachtree Rd NE, Atlanta, GA 30305
# 1           2020 Powers Ferry Rd SE, Atlanta, GA 30339
# 2    290 Martin Luther King Jr Dr SE, Atlanta, GA 3...
# 3     7227 NE Peachtree Dunwoody Rd, Atlanta, GA 30328
# 4                   707 Park Ave NE, Atlanta, GA 30326
# ..                                                 ...
# 399     3000 Continental Colony Pky, Atlanta, GA 30331
# 400     1900 N Druid Hills Rd NE, Brookhaven, GA 30319
# 401             1600 Tibarron Pky SE, Smyrna, GA 30080
# 402             4241 Hendrix Dr, Forest Park, GA 30297
# 403               3200 Desert Dr, East Point, GA 30344
#
#                                    LISTING_DESCRIPTION  HAS_VIDEOS  \
# 0    Dog & Cat Friendly, Fitness Center, Pool, Kitc...        True
# 1    Dog & Cat Friendly, Fitness Center, Pool, Ceil...       False
# 2    Dog & Cat Friendly, Fitness Center, Pool, Dish...        True
# 3    Dog & Cat Friendly, Fitness Center, Dishwasher...        True
# 4    Dog & Cat Friendly, In Unit Washer & Dryer, Gr...       False
# ..                                                 ...         ...
# 399                                                NaN       False
# 400                                                NaN       False
# 401                                                NaN       False
# 402                                                NaN       False
# 403                                                NaN       False
#
#      HAS_VIRTUAL_TOUR  HAS_EMAIL           PRICE    PHONE_NUMBER  HAS_IMAGE  \
# 0                True       True  $1,737 - 3,557  (470) 870-7791       True
# 1                True       True  $1,392 - 2,836  (470) 837-5393       True
# 2                True       True  $1,312 - 2,218  (470) 823-9464       True
# 3                True       True  $1,094 - 1,728  (844) 757-0487       True
# 4                True       True  $1,322 - 2,457  (470) 944-5573       True
# ..                ...        ...             ...             ...        ...
# 399              True       True    $699 - 1,250  (470) 944-6244       True
# 400              True       True  $1,294 - 3,019  (470) 670-0205       True
# 401              True       True  $1,125 - 2,012  (470) 823-2429       True
# 402             False       True          $1,295  (470) 944-3437       True
# 403              True       True    $863 - 3,248  (470) 944-6321       True
#
#      SPECIAL_TEXT
# 0    1 Month Free
# 1    1 Month Free
# 2            None
# 3            None
# 4       Discounts
# ..            ...
# 399          None
# 400          None
# 401          None
# 402          None
# 403          None
#
# [404 rows x 14 columns]
